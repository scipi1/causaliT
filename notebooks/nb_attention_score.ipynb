# %%
from os.path import dirname, abspath
import sys
import matplotlib.pyplot as plt


root_path = dirname(abspath("./"))
import sys
sys.path.append(root_path)
from causaliT.evaluation.predict import *
from notebooks.lib import *

# plotting standard settings
plt.rcParams['figure.dpi'] = 100 #360 # standard is 360 but for set to 100 for practical visualization on the notebook
plt.rcParams['axes.labelsize'] = 18
plt.rcParams['axes.titlesize'] = 18
plt.rcParams['xtick.labelsize'] = 16
plt.rcParams['ytick.labelsize'] = 16
plt.rcParams['legend.fontsize'] = 14
plt.rcParams['figure.figsize'] = (6, 6)
plt.rcParams['lines.linewidth'] = 1.5

# %% [markdown]
# ## Load Experiment

# %%
data = load_attention_data("../experiments/euler_scm6/stage_Lie_scm6_54094964")
fig = plot_attention_scores(data, cmap='viridis', annotation_fontsize=8, scale_mode="row")
plt.show()
# Out:
# Seed set to 42
# Detected architecture: StageCausalForecaster
# Found 5 k-fold directories: ['k_0', 'k_1', 'k_2', 'k_3', 'k_4']
# Processing k_0: epoch=9-train_loss=0.00.ckpt
# c:\Users\ScipioneFrancesco\Documents\Projects\causaliT\venv\Lib\site-packages\torch\__init__.py:1617: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\aten\src\ATen\Context.cpp:85.)
#   _C._set_float32_matmul_precision(precision)
# Loading single data file (S, X, Y format).
# Data shapes - S: (50000, 3, 2), X: (50000, 2, 2), Y: (50000, 2, 2)
# Loading single data file (S, X, Y format).
# Data shapes - S: (50000, 3, 2), X: (50000, 2, 2), Y: (50000, 2, 2)
# Test dataset selected.
# Predicting...
# 100%|██████████| 157/157 [00:05<00:00, 28.18it/s]
# Seed set to 42
#   Attention weights keys: dict_keys(['dec1_cross', 'dec1_self', 'dec2_cross', 'dec2_self'])
#   ✓ Successfully processed k_0
# Processing k_1: epoch=9-train_loss=0.00.ckpt
# Loading single data file (S, X, Y format).
# Data shapes - S: (50000, 3, 2), X: (50000, 2, 2), Y: (50000, 2, 2)
# Loading single data file (S, X, Y format).
# Data shapes - S: (50000, 3, 2), X: (50000, 2, 2), Y: (50000, 2, 2)
# Test dataset selected.
# Predicting...
# 100%|██████████| 157/157 [00:06<00:00, 25.43it/s]
# Seed set to 42
#   Attention weights keys: dict_keys(['dec1_cross', 'dec1_self', 'dec2_cross', 'dec2_self'])
#   ✓ Successfully processed k_1
# Processing k_2: epoch=9-train_loss=0.02.ckpt
# Loading single data file (S, X, Y format).
# Data shapes - S: (50000, 3, 2), X: (50000, 2, 2), Y: (50000, 2, 2)
# Loading single data file (S, X, Y format).
# Data shapes - S: (50000, 3, 2), X: (50000, 2, 2), Y: (50000, 2, 2)
# Test dataset selected.
# Predicting...
# 100%|██████████| 157/157 [00:06<00:00, 24.07it/s]
# Seed set to 42
#   Attention weights keys: dict_keys(['dec1_cross', 'dec1_self', 'dec2_cross', 'dec2_self'])
#   ✓ Successfully processed k_2
# Processing k_3: epoch=9-train_loss=0.00.ckpt
# Loading single data file (S, X, Y format).
# Data shapes - S: (50000, 3, 2), X: (50000, 2, 2), Y: (50000, 2, 2)
# Loading single data file (S, X, Y format).
# Data shapes - S: (50000, 3, 2), X: (50000, 2, 2), Y: (50000, 2, 2)
# Test dataset selected.
# Predicting...
# 100%|██████████| 157/157 [00:06<00:00, 24.74it/s]
# Seed set to 42
#   Attention weights keys: dict_keys(['dec1_cross', 'dec1_self', 'dec2_cross', 'dec2_self'])
#   ✓ Successfully processed k_3
# Processing k_4: epoch=9-train_loss=3.63.ckpt
# Loading single data file (S, X, Y format).
# Data shapes - S: (50000, 3, 2), X: (50000, 2, 2), Y: (50000, 2, 2)
# Loading single data file (S, X, Y format).
# Data shapes - S: (50000, 3, 2), X: (50000, 2, 2), Y: (50000, 2, 2)
# Test dataset selected.
# Predicting...
# 100%|██████████| 157/157 [00:06<00:00, 22.44it/s]
#   Attention weights keys: dict_keys(['dec1_cross', 'dec1_self', 'dec2_cross', 'dec2_self'])
#   ✓ Successfully processed k_4
#
# Loaded data from 5 folds
# Global color scale: min=-0.0286, max=4.5370
# Row 0 (decoder1_self, phi=False) scale: min=-0.0231, max=4.5370
# Row 1 (decoder1_self, phi=True) scale: min=-0.0148, max=3.0303
# Row 2 (decoder1_cross, phi=False) scale: min=0.0085, max=0.4962
# Row 3 (decoder2_self, phi=False) scale: min=-0.0032, max=1.0343
# Row 4 (decoder2_self, phi=True) scale: min=-0.0286, max=1.4273
# Row 5 (decoder2_cross, phi=False) scale: min=0.0001, max=1.0000
# c:\Users\ScipioneFrancesco\Documents\Projects\causaliT\notebooks\lib.py:615: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
data = load_attention_data("../experiments/euler_scm6/stage_SoftMax_scm6_54103044")
fig = plot_attention_scores(data, cmap='viridis', annotation_fontsize=8, scale_mode="row")
plt.show()
# Out:
# Seed set to 42
# Detected architecture: StageCausalForecaster
# Found 5 k-fold directories: ['k_0', 'k_1', 'k_2', 'k_3', 'k_4']
# Processing k_0: epoch=9-train_loss=0.00.ckpt
# Loading single data file (S, X, Y format).
# Data shapes - S: (50000, 3, 2), X: (50000, 2, 2), Y: (50000, 2, 2)
# Loading single data file (S, X, Y format).
# Data shapes - S: (50000, 3, 2), X: (50000, 2, 2), Y: (50000, 2, 2)
# Test dataset selected.
# Predicting...
# 100%|██████████| 157/157 [00:05<00:00, 26.96it/s]
# Seed set to 42
#   Attention weights keys: dict_keys(['dec1_cross', 'dec1_self', 'dec2_cross', 'dec2_self'])
#   ✓ Successfully processed k_0
# Processing k_1: epoch=9-train_loss=0.00.ckpt
# Loading single data file (S, X, Y format).
# Data shapes - S: (50000, 3, 2), X: (50000, 2, 2), Y: (50000, 2, 2)
# Loading single data file (S, X, Y format).
# Data shapes - S: (50000, 3, 2), X: (50000, 2, 2), Y: (50000, 2, 2)
# Test dataset selected.
# Predicting...
# 100%|██████████| 157/157 [00:06<00:00, 25.98it/s]
# Seed set to 42
#   Attention weights keys: dict_keys(['dec1_cross', 'dec1_self', 'dec2_cross', 'dec2_self'])
#   ✓ Successfully processed k_1
# Processing k_2: epoch=9-train_loss=0.00.ckpt
# Loading single data file (S, X, Y format).
# Data shapes - S: (50000, 3, 2), X: (50000, 2, 2), Y: (50000, 2, 2)
# Loading single data file (S, X, Y format).
# Data shapes - S: (50000, 3, 2), X: (50000, 2, 2), Y: (50000, 2, 2)
# Test dataset selected.
# Predicting...
# 100%|██████████| 157/157 [00:05<00:00, 26.70it/s]
# Seed set to 42
#   Attention weights keys: dict_keys(['dec1_cross', 'dec1_self', 'dec2_cross', 'dec2_self'])
#   ✓ Successfully processed k_2
# Processing k_3: epoch=9-train_loss=0.00.ckpt
# Loading single data file (S, X, Y format).
# Data shapes - S: (50000, 3, 2), X: (50000, 2, 2), Y: (50000, 2, 2)
# Loading single data file (S, X, Y format).
# Data shapes - S: (50000, 3, 2), X: (50000, 2, 2), Y: (50000, 2, 2)
# Test dataset selected.
# Predicting...
# 100%|██████████| 157/157 [00:06<00:00, 24.86it/s]
# Seed set to 42
#   Attention weights keys: dict_keys(['dec1_cross', 'dec1_self', 'dec2_cross', 'dec2_self'])
#   ✓ Successfully processed k_3
# Processing k_4: epoch=9-train_loss=0.00.ckpt
# Loading single data file (S, X, Y format).
# Data shapes - S: (50000, 3, 2), X: (50000, 2, 2), Y: (50000, 2, 2)
# Loading single data file (S, X, Y format).
# Data shapes - S: (50000, 3, 2), X: (50000, 2, 2), Y: (50000, 2, 2)
# Test dataset selected.
# Predicting...
# 100%|██████████| 157/157 [00:25<00:00,  6.06it/s]
#   Attention weights keys: dict_keys(['dec1_cross', 'dec1_self', 'dec2_cross', 'dec2_self'])
#   ✓ Successfully processed k_4
#
# Loaded data from 5 folds
# Global color scale: min=0.0093, max=0.9875
# Row 0 (decoder1_self, phi=False) scale: min=0.0125, max=0.9875
# Row 1 (decoder1_cross, phi=False) scale: min=0.0093, max=0.5063
# Row 2 (decoder2_self, phi=False) scale: min=0.1257, max=0.8743
# Row 3 (decoder2_cross, phi=False) scale: min=0.0125, max=0.9875
