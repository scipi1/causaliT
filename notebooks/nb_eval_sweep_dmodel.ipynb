# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from os.path import join

# %% [markdown]
# # Uniform Sampling

# %%
exp_path = "../experiments/noise_aware_single/scm1/euler/sweep_d_model_60863422/eval/eval_d_model_sweep"
df = pd.read_csv(join(exp_path, "files/sweep_summary.csv"))
df["d_model_hue"] = df["d_model"].astype(str)
df["shd_tot"] = df["shd_cross"] + df["shd_self"]
df['shd_tot_norm_by_group'] = df['shd_tot'] / df.groupby('d_model')['shd_tot'].transform('max')
df['test_loss_centered'] = (df['test_loss'] - df.groupby('d_model')['test_loss'].transform('min')) #/ df.groupby('d_model')['test_loss'].transform('max')
df['test_loss_norm_by_group'] = df['test_loss_centered'] / df.groupby('d_model')['test_loss_centered'].transform('max')
print(df.columns)

fig = plt.figure()
sns.boxplot(df, x="d_model_hue", y="test_loss")

fig = plt.figure()
sns.boxplot(df, x="d_model_hue", y="shd_tot")

fig = plt.figure()
sns.scatterplot(df, x="test_loss", y="shd_cross", hue="d_model_hue")
plt.yscale("log")

fig = plt.figure()
sns.scatterplot(df, x="test_loss", y="shd_self", hue="d_model_hue")
plt.yscale("log")

fig = plt.figure()
sns.scatterplot(df, x="test_loss", y="shd_tot", hue="d_model_hue")
plt.yscale("log")

fig = plt.figure()
sns.scatterplot(df, x="test_loss", y="test_hsic", hue="d_model_hue")
plt.yscale("log")
plt.title("Discrete $S$ sampling")

fig = plt.figure()
sns.scatterplot(df, x="shd_tot", y="test_hsic", hue="d_model_hue")
plt.yscale("log")
plt.title("Discrete $S$ sampling")

fig = plt.figure()
sns.scatterplot(df, x="shd_tot", y="val_hsic_mean_over_epochs", hue="d_model_hue")
plt.yscale("log")
plt.title("Discrete $S$ sampling")

fig = plt.figure()
sns.scatterplot(df, x="shd_tot", y="train_hsic_mean_over_epochs", hue="d_model_hue")
plt.yscale("log")
plt.title("Discrete $S$ sampling")
# Out:
# Index(['run_name', 'd_model', 'seed', 'fold', 'test_hsic', 'val_hsic',
#        'test_loss', 'val_loss', 'test_r2', 'val_r2', 'test_mae', 'val_mae',
#        'test_rmse', 'val_rmse', 'shd_cross', 'shd_self',
#        'train_hsic_mean_over_epochs', 'train_hsic_max_over_epochs',
#        'train_hsic_min_over_epochs', 'train_hsic_final',
#        'val_hsic_mean_over_epochs', 'val_hsic_max_over_epochs',
#        'val_hsic_min_over_epochs', 'val_hsic_final', 'd_model_hue', 'shd_tot',
#        'shd_tot_norm_by_group', 'test_loss_centered',
#        'test_loss_norm_by_group'],
#       dtype='object')
# Text(0.5, 1.0, 'Discrete $S$ sampling')

# %% [markdown]
# # Dicrete sampling

# %%
exp_path = "../experiments/noise_aware_single/scm1/euler/sweep_d_model_61106018/eval/eval_d_model_sweep"
df = pd.read_csv(join(exp_path, "files/sweep_summary.csv"))
df["d_model_hue"] = df["d_model"].astype(str)
df["shd_tot"] = df["shd_cross"] + df["shd_self"]
df['shd_tot_norm_by_group'] = df['shd_tot'] / df.groupby('d_model')['shd_tot'].transform('max')
df['test_loss_centered'] = (df['test_loss'] - df.groupby('d_model')['test_loss'].transform('min')) #/ df.groupby('d_model')['test_loss'].transform('max')
df['test_loss_norm_by_group'] = df['test_loss_centered'] / df.groupby('d_model')['test_loss_centered'].transform('max')

fig = plt.figure()
sns.boxplot(df, x="d_model_hue", y="test_loss")

fig = plt.figure()
sns.boxplot(df, x="d_model_hue", y="shd_tot")

fig = plt.figure()
sns.scatterplot(df, x="test_loss", y="shd_cross", hue="d_model_hue")
plt.yscale("log")

fig = plt.figure()
sns.scatterplot(df, x="test_loss", y="shd_self", hue="d_model_hue")
plt.yscale("log")

fig = plt.figure()
sns.scatterplot(df, x="test_loss", y="shd_tot", hue="d_model_hue")
plt.yscale("log")

fig = plt.figure()
sns.scatterplot(df, x="test_loss", y="test_hsic", hue="d_model_hue")
plt.yscale("log")
plt.title("Discrete $S$ sampling")

fig = plt.figure()
sns.scatterplot(df, x="shd_tot", y="test_hsic", hue="d_model_hue")
plt.yscale("log")
plt.title("Discrete $S$ sampling")

fig = plt.figure()
sns.scatterplot(df, x="shd_tot", y="val_hsic_mean_over_epochs", hue="d_model_hue")
plt.yscale("log")
plt.title("Discrete $S$ sampling")

fig = plt.figure()
sns.scatterplot(df, x="shd_tot", y="train_hsic_mean_over_epochs", hue="d_model_hue")
plt.yscale("log")
plt.title("Discrete $S$ sampling")
# Out:
# Text(0.5, 1.0, 'Discrete $S$ sampling')

# %% [markdown]
# # Discrete sampling + holdout

# %%
exp_path = "../experiments/noise_aware_single/scm1/euler/sweep_d_model_hold_61198451/eval/eval_d_model_sweep"

df = pd.read_csv(join(exp_path, "files/sweep_summary.csv"))
df["d_model_hue"] = df["d_model"].astype(str)
df["shd_tot"] = df["shd_cross"] + df["shd_self"]
df['shd_tot_norm_by_group'] = df['shd_tot'] / df.groupby('d_model')['shd_tot'].transform('max')
df['test_loss_centered'] = (df['test_loss'] - df.groupby('d_model')['test_loss'].transform('min')) #/ df.groupby('d_model')['test_loss'].transform('max')
df['test_loss_norm_by_group'] = df['test_loss_centered'] / df.groupby('d_model')['test_loss_centered'].transform('max')

fig = plt.figure()
sns.boxplot(df, x="d_model_hue", y="test_loss")

fig = plt.figure()
sns.boxplot(df, x="d_model_hue", y="shd_tot")

fig = plt.figure()
sns.scatterplot(df, x="test_loss", y="shd_cross", hue="d_model_hue")
plt.yscale("log")

fig = plt.figure()
sns.scatterplot(df, x="test_loss", y="shd_self", hue="d_model_hue")
plt.yscale("log")

fig = plt.figure()
sns.scatterplot(df, x="test_loss", y="shd_tot", hue="d_model_hue")
plt.yscale("log")

fig = plt.figure()
sns.scatterplot(df, x="test_loss", y="test_hsic", hue="d_model_hue")
plt.yscale("log")
plt.title("Discrete $S$ sampling")

fig = plt.figure()
sns.scatterplot(df, x="shd_tot", y="test_hsic", hue="d_model_hue")
plt.yscale("log")
plt.title("Discrete $S$ sampling")

fig = plt.figure()
sns.scatterplot(df, x="shd_tot", y="val_hsic_mean_over_epochs", hue="d_model_hue")
plt.yscale("log")
plt.title("Discrete $S$ sampling")

fig = plt.figure()
sns.scatterplot(df, x="shd_tot", y="train_hsic_mean_over_epochs", hue="d_model_hue")
plt.yscale("log")
plt.title("Discrete $S$ sampling")
# Out:
# Text(0.5, 1.0, 'Discrete $S$ sampling')
